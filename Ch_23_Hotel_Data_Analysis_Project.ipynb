# %% [markdown]
# # Data isn’t just numbers, but a narrative waiting to be uncovered.

# %% [raw]
# What is EDA?
# EDA means to understand the dataset better. Almost all data analytics or data science professionals do this process before generating insights or doing data modeling. In real life, this process took a lot of time, depending on the complexity and completeness of the dataset we have.
#
# That’s why using Python, some packages help to do that process faster and easier. Because it shows us a summary, before we focus to explore deeper any variables we find interesting.

# %% [markdown]
# # Importing Modules

# %% [markdown]
# Matplotlib & Seaborn is a Python library that allows us to plot graphs and plots that help us extract useful insights from data 🐍📊.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# it is used to display graph with single statement of code.

# %% [markdown]
# # Reading Data

# %% [markdown]
# The first step in the data-cleaning process is to read the data.

# %%
hotel = pd.read_csv('tips.csv')

# => pandas.read_csv() is used to access csv file in the python 
# program.
# => It is used to access data offline, but we need to specify 
# file path.
# => If csv file is located on the same location where program 
# file exists, then no need to specify the file path.
# => Ex: tips = pd.read_csv('C:\\Users\\Dell\\Desktop\\tips.csv')
# => Suppose we have online dataset, we need to involve 
# it like below :
# tips = sns.load_dataset('URL')

# %% [markdown]
# # The “80/20 rule” applies: 80 percent of a data analyst or scientist’s valuable time is spent simply finding, cleansing, and organizing data, leaving only 20 percent to perform analysis.

# %% [markdown]
# # Observing Data

# %%
hotel
# here all data will get loaded.
# Out:
#      total_bill   tip  gender smoker   day    time  team_size
# 0         16.99  1.01  Female     No   Sun  Dinner          2
# 1         10.34  1.66    Male     No   Sun  Dinner          3
# 2         21.01  3.50    Male     No   Sun  Dinner          3
# 3         23.68  3.31    Male     No   Sun  Dinner          2
# 4         24.59  3.61  Female     No   Sun  Dinner          4
# ..          ...   ...     ...    ...   ...     ...        ...
# 239       29.03  5.92    Male     No   Sat  Dinner          3
# 240       27.18  2.00  Female    Yes   Sat  Dinner          2
# 241       22.67  2.00    Male    Yes   Sat  Dinner          2
# 242       17.82  1.75    Male     No   Sat  Dinner          2
# 243       18.78  3.00  Female     No  Thur  Dinner          2
#
# [244 rows x 7 columns]

# %%
hotel.info()
# to display information of tips dataset.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   gender      244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   team_size   244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
#hotel.head()
hotel.tail(10)
# it is used to display specific no. of records.
# by default head() will print first 5 records.
# Ex: hotel.head(20)
# It will display first 20 records.
# Out:
#      total_bill   tip  gender smoker   day    time  team_size
# 234       15.53  3.00    Male    Yes   Sat  Dinner          2
# 235       10.07  1.25    Male     No   Sat  Dinner          2
# 236       12.60  1.00    Male    Yes   Sat  Dinner          2
# 237       32.83  1.17    Male    Yes   Sat  Dinner          2
# 238       35.83  4.67  Female     No   Sat  Dinner          3
# 239       29.03  5.92    Male     No   Sat  Dinner          3
# 240       27.18  2.00  Female    Yes   Sat  Dinner          2
# 241       22.67  2.00    Male    Yes   Sat  Dinner          2
# 242       17.82  1.75    Male     No   Sat  Dinner          2
# 243       18.78  3.00  Female     No  Thur  Dinner          2

# %%
# check if we have the null values or not.
print(hotel.isnull().sum())
# Out:
# total_bill    0
# tip           0
# gender        0
# smoker        0
# day           0
# time          0
# team_size     0
# dtype: int64

# %%
hotel['day'].unique()
# to display unique days are availibale
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
hotel['day'].nunique()
# to display how many unique size are availibale
# Out:
# 4

# %%
# want to analyse total_bill paid
sns.distplot(hotel['total_bill'])
# this plot works on single dimesnion / column
# Out:
# C:\Users\Bhavesh Joshi\AppData\Local\Temp\ipykernel_15044\2114591702.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(hotel['total_bill'])
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
# => here kde is used to print line on the bars, default it is 'True'
# => bins is used to display how much bars we want on the bar-chart.

sns.distplot(hotel['total_bill'], kde=False, bins=20)
# Out:
# C:\Users\Bhavesh Joshi\AppData\Local\Temp\ipykernel_15044\358827930.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(hotel['total_bill'], kde=False, bins=20)
# <Axes: xlabel='total_bill'>

# %%
# we want to find the relation between total_bill & tips
sns.jointplot('total_bill', 'tip', hotel)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 2
#       1 # we want to find the relation between total_bill & tips
# ----> 2 sns.jointplot('total_bill', 'tip', hotel)
#
# TypeError: jointplot() takes from 0 to 1 positional arguments but 3 were given

# %%
# if we want to compare every numerical category data type in the 
# datasets with each other..
sns.pairplot(hotel)

# %%
 sns.pairplot(hotel, hue='gender')
# want to visualise relation between smokers & every categorised datasets

# %%
# we want only curve but not bars
sns.kdeplot(hotel['total_bill'])

# %%
hotel.head()
# Out:
#    total_bill   tip  gender smoker  day    time  team_size
# 0       16.99  1.01  Female     No  Sun  Dinner          2
# 1       10.34  1.66    Male     No  Sun  Dinner          3
# 2       21.01  3.50    Male     No  Sun  Dinner          3
# 3       23.68  3.31    Male     No  Sun  Dinner          2
# 4       24.59  3.61  Female     No  Sun  Dinner          4

# %%
# to visualize how many males & females come in the hotel
sns.countplot(x = 'gender', data=hotel)

# %%
sns.countplot(x = 'smoker', data = hotel)
#sns.countplot(x = 'day', data = hotel)
#sns.countplot(x = 'team_size', data = hotel)

# we can visualize that the count of smokers smoke
# we can visualize that on saturday most of the people come
# we can visualize that 2 size of peoples come more no of times
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
# want to find how many are smokers in males & females 
#sns.countplot(x = 'gender', data = hotel, hue = 'smoker')
sns.countplot(x = 'day', data = hotel, hue = 'gender')

# %%
sns.countplot(x = 'time', data=hotel, hue = 'gender')

# %%
# want to know total bill (Average) paid by male & females
sns.barplot(x = 'gender', y = 'total_bill', data = hotel)

# %%
sns.barplot( y = 'tip',x = 'day', data = hotel)
# this will show average tips/day

# %%
sns.violinplot(x = 'day', y = 'total_bill', data = hotel)
# day wise total bill

# %%
sns.violinplot(x = 'day', y = 'total_bill', data = hotel, hue = 'gender')

# %%
sns.violinplot(x = 'day', y = 'total_bill', data = hotel, hue = 'gender', 
               split=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x = 'day', y='total_bill', data= hotel)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
hotel.head()
# Out:
#    total_bill   tip  gender smoker  day    time  team_size
# 0       16.99  1.01  Female     No  Sun  Dinner          2
# 1       10.34  1.66    Male     No  Sun  Dinner          3
# 2       21.01  3.50    Male     No  Sun  Dinner          3
# 3       23.68  3.31    Male     No  Sun  Dinner          2
# 4       24.59  3.61  Female     No  Sun  Dinner          4

# %%
# if we want to compare every numerical category data type in the datasets with each other..
sns.pairplot(hotel)

# %%
# co-relation
hotel.corr()

# this will represent accuracy of the analysis
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[76], line 2
#       1 # co-relation
# ----> 2 hotel.corr()
#       3 hotel
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# ...

# %%
sns.heatmap(hotel.corr())
# light the color = more relational accuracy & dark color = less relational accuracy
# color shades changes according to its Accuracy.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 sns.heatmap(hotel.corr())
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# ...
